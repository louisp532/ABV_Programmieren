# %%
print("Hello World")
# Out:
# Hello World

# %%
zahlen = 101

print(zahlen)
# Out:
# 101

# %%
zahl = 10

print(type(zahl))
# Out:
# <class 'int'>

# %%
"ha"*3
# Out:
# 'hahaha'

# %%
"Ha "*3
# Out:
# 'Ha Ha Ha '

# %%
s = "PYTHON"
print(s[0], s[-1], s[1:4], s[:3])
# Out:
# P N YTH PYT
